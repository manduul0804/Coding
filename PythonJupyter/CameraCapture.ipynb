# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
cap = cv2.VideoCapture(2)
ret, frame = cap.read()

# %%
print(ret)
# Out:
# True

# %%
print(frame)
# Out:
# [[[236 250 252]
#   [236 250 252]
#   [236 250 252]
#   ...
#   [153   0 111]
#   [149   0  88]
#   [149   0  88]]
#
#  [[236 250 252]
#   [236 250 252]
#   [236 250 252]
#   ...
#   [151   0  94]
#   [150   0  91]
#   [150   0  91]]
#
#  [[236 250 252]
#   [236 250 252]
#   [236 250 252]
#   ...
#   [151   0  97]
#   [152   0 100]
#   [154   0 119]]
#
#  ...
#
#  [[  4 208 252]
#   [  2 196 252]
#   [ 57 231 252]
#   ...
#   [142   0  61]
#   [134   0  44]
#   [132   0  41]]
#
#  [[  1 189 252]
#   [  1 192 252]
#   [  3 202 252]
#   ...
#   [142   0  61]
#   [136   0  47]
#   [128   0  36]]
#
#  [[  0 152 248]
#   [  0 154 248]
#   [  0 184 252]
#   ...
#   [132   0  41]
#   [120   0  25]
#   [138   0  49]]]

# %%
plt.imshow(frame)

# %%
cap = cv2.VideoCapture(2)
while cap.isOpened():
    ret, frame = cap.read()

    # Show image
    cv2.imshow('Webcam', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb Cell 7 in 1
# ----> <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> cap = cv2.VideoCapture(2)
#
# NameError: name 'cv2' is not defined
