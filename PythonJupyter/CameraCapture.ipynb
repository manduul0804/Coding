# %%
import cv2
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
cap = cv2.VideoCapture(2)
ret, frame = cap.read()

# %%
print(ret)
# Out:
# True

# %%
print(frame)
# Out:
# [[[141   7 189]
#   [142   6 188]
#   [146   2 183]
#   ...
#   [151   0 169]
#   [144   4 185]
#   [145   3 184]]
#
#  [[136  12 195]
#   [139   9 191]
#   [136  12 195]
#   ...
#   [149   0 178]
#   [149   0 178]
#   [146   2 183]]
#
#  [[136  12 195]
#   [138  10 193]
#   [137  11 194]
#   ...
#   [149   0 178]
#   [150   0 173]
#   [151   0 167]]
#
#  ...
#
#  [[149   0 176]
#   [156   0 139]
#   [155   0 130]
#   ...
#   [142   0  61]
#   [147   0  79]
#   [142   0  58]]
#
#  [[149   0 178]
#   [153   0 160]
#   [156   0 144]
#   ...
#   [143   0  64]
#   [142   0  61]
#   [147   0  79]]
#
#  [[153   0 160]
#   [153   0 160]
#   [152   0 162]
#   ...
#   [134   0  44]
#   [144   0  67]
#   [138   0  49]]]

# %%
plt.imshow(frame)

# %%
cap = cv2.VideoCapture(2)
while cap.isOpened():
    ret, frame = cap.read()

    # Show image
    cv2.imshow('Webcam', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb Cell 7 in 3
#       <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> cap = cv2.VideoCapture(2)
#       <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> while cap.isOpened():
# ----> <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     ret, frame = cap.read()
#       <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     # Show image
#       <a href='vscode-notebook-cell:/home/manduul/Github/Coding/PythonJupyter/CameraCapture.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>     cv2.imshow('Webcam', frame)
#
# KeyboardInterrupt:

# %%
cap = cv2.VideoCapture(2)

# %%
cap.isOpened()
# Out:
# True

# %%
cap.release()
